# %% [markdown]
# # Exoplanet status prediction using Gradient Boosting Classifier
#
# Data column meanings:
# https://exoplanetarchive.ipac.caltech.edu/docs/API_kepcandidate_columns.html#proj_disp_col
# * koi_disposition:
#     * CANDIDATE: A planetary candidate has passed all prior tests conducted to identify false positives, although this does not a priori mean that all possible tests have been conducted. A future test may confirm this KOI as a false positive.
#
#     * FALSE POSITIVE: A false positive has failed at least one of the tests described in Batalha et al. (2012).
#
#     * CONFIRMED: Cleary an exoplanet
#
# A planetary candidate has passed all prior tests conducted to identify false positives, although this does not a priori mean that all possible tests have been conducted. A future test may confirm this KOI as a false positive. False positives can occur when: 1) the KOI is in reality an eclipsing binary star, 2) the Kepler light curve is contaminated by a background eclipsing binary, 3) stellar variability is confused for coherent planetary transits, or 4) instrumental artifacts are confused for coherent planetary transits.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV

import matplotlib.pyplot as plt

# %% [markdown]
# As a first step I load the data and separate it into two DataFrames.
#
# One DataFrame will have the yet to be classified space objects, and the other one will have the objects already classified as an exoplanet or not.

# %%
exoplanet_data = pd.read_csv("exoplanet_data.csv")

# Drop the null rows
exoplanet_data = exoplanet_data.dropna()

#Create new DataFrame for candidate expoplanets
#candidate_exoplanets = exoplanet_data[exoplanet_data['koi_disposition'] == 'CANDIDATE']

# Filter out the planets labeled as candidates
#exoplanet_data = exoplanet_data[exoplanet_data['koi_disposition'] != 'CANDIDATE']

# %%
exoplanet_data.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
# Select from the second column to the last as X
X = exoplanet_data.iloc[:, 1:]
feature_names = X.columns

# Select koi_disposition as y
y= exoplanet_data['koi_disposition']

# %% [markdown]
# Now I scale the X dataframe so its values range from 0 to 1 and then split it in training and testing sets

# %%
# Define scaler object
scaler = MinMaxScaler().fit(X)

# Scale X
X_scaled = scaler.transform(X)

#Train test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, stratify = y, random_state = 42)

# %% [markdown]
# ## Gradient Boosting Classifier training and testing

# %% [markdown]
# Gradient Boosting Classifiers are a series of trees that are strongly pre-pruned before the training.
#
# Each new tree tries to correct the mistakes of the previous one with the learning_rate parameter. How many trees are created is controlled with the n_estimators parameter.

# %%
param_grid = {'learning_rate': [0.001, 0.01, 0.05, 0.1, 0.5, 1],
              'n_estimators': [50, 75, 100, 125, 150, 175, 200],
              'max_depth': [4,5,6,7,8,9,10]}
grid = GridSearchCV(GradientBoostingClassifier(), param_grid, verbose=3)

# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_train, y_train)
# Out:
# C:\Users\luisc\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 294 candidates, totalling 882 fits
# [CV] learning_rate=0.001, max_depth=4, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=50, score=0.5011441647597255, total=   1.7s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=50 ...............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=50, score=0.5011441647597255, total=   1.6s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=50 ...............
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.4s remaining:    0.0s
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=50, score=0.5014310246136233, total=   1.6s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=75, score=0.5011441647597255, total=   2.3s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=75, score=0.5011441647597255, total=   2.3s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=75, score=0.5014310246136233, total=   2.3s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=100, score=0.6167048054919908, total=   3.6s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=100, score=0.5011441647597255, total=   3.2s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=100, score=0.7624499141385231, total=   3.0s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=125, score=0.7694508009153318, total=   4.2s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=125, score=0.7934782608695652, total=   4.2s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=125, score=0.7704636519748139, total=   4.0s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=150, score=0.7694508009153318, total=   4.5s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=150, score=0.8020594965675057, total=   4.7s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=150, score=0.8277046365197481, total=   5.0s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=175, score=0.8667048054919908, total=   5.4s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=175, score=0.868421052631579, total=   5.6s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=175, score=0.8551803091013166, total=   5.7s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=200, score=0.8672768878718535, total=   6.3s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=200, score=0.8689931350114416, total=   7.3s
# [CV] learning_rate=0.001, max_depth=4, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=4, n_estimators=200, score=0.8574699484831139, total=   6.5s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=50, score=0.5011441647597255, total=   2.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=50, score=0.5011441647597255, total=   2.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=50, score=0.5014310246136233, total=   2.2s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=75, score=0.5011441647597255, total=   3.3s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=75, score=0.5011441647597255, total=   3.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=75, score=0.5014310246136233, total=   3.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100, score=0.7585812356979404, total=   4.6s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100, score=0.7454233409610984, total=   4.7s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100, score=0.7601602747567258, total=   4.2s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=125, score=0.7643020594965675, total=   6.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=125, score=0.7877574370709383, total=   5.9s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=125, score=0.7716084716657127, total=   5.2s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=150, score=0.8283752860411899, total=   6.9s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=150, score=0.8627002288329519, total=   6.5s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=150, score=0.8420148826559817, total=   6.7s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=175, score=0.868421052631579, total=   9.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=175, score=0.8672768878718535, total=   8.6s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=175, score=0.8511734401831712, total=   8.6s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200, score=0.8724256292906178, total=  10.4s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200, score=0.870137299771167, total=  10.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200, score=0.8706353749284488, total=  10.0s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=50, score=0.5011441647597255, total=   3.1s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=50, score=0.5011441647597255, total=   3.4s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=50, score=0.5014310246136233, total=   3.8s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=75, score=0.5011441647597255, total=   5.7s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=75, score=0.5011441647597255, total=   4.9s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=75, score=0.5014310246136233, total=   4.6s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=100, score=0.7477116704805492, total=   6.2s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=100, score=0.7471395881006865, total=   5.6s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=100, score=0.7687464224384659, total=   5.7s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=125, score=0.8255148741418764, total=   7.0s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=125, score=0.8209382151029748, total=   8.0s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=125, score=0.8328563251287923, total=   7.0s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=150, score=0.8381006864988558, total=  10.1s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=150, score=0.8575514874141876, total=   8.6s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=150, score=0.8528906697195192, total=  10.3s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=175, score=0.8707093821510298, total=  14.4s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=175, score=0.8655606407322655, total=  12.1s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=175, score=0.8568975386376646, total=  10.2s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=200, score=0.879862700228833, total=  12.3s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=200, score=0.8787185354691075, total=  13.5s
# [CV] learning_rate=0.001, max_depth=6, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=6, n_estimators=200, score=0.8620492272467086, total=  12.9s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=50, score=0.5011441647597255, total=   3.3s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=50, score=0.5011441647597255, total=   3.2s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=50, score=0.5014310246136233, total=   3.3s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=75, score=0.5011441647597255, total=   6.3s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=75, score=0.5011441647597255, total=   5.0s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=75, score=0.5014310246136233, total=   4.8s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=100, score=0.7631578947368421, total=   7.2s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=100, score=0.7465675057208238, total=   6.6s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=100, score=0.7578706353749285, total=   7.6s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=125, score=0.8232265446224256, total=   8.9s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=125, score=0.8226544622425629, total=   9.0s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=125, score=0.8483113909559244, total=   8.2s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=150, score=0.8461098398169337, total=  10.4s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=150, score=0.8392448512585813, total=  11.1s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=150, score=0.8557527189467659, total=  11.0s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=175, score=0.8667048054919908, total=  13.4s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=175, score=0.8747139588100686, total=  13.1s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=175, score=0.8597595878649112, total=  11.6s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=200, score=0.8827231121281465, total=  13.6s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=200, score=0.8804347826086957, total=  13.7s
# [CV] learning_rate=0.001, max_depth=7, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=7, n_estimators=200, score=0.864338866628506, total=  13.2s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=50, score=0.5011441647597255, total=   3.8s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=50, score=0.5011441647597255, total=   3.6s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=50, score=0.5014310246136233, total=   3.4s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=75, score=0.5011441647597255, total=   5.6s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=75, score=0.5011441647597255, total=   5.8s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=75, score=0.5014310246136233, total=   5.4s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=100, score=0.7625858123569794, total=   8.0s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=100, score=0.7923340961098398, total=   7.5s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=100, score=0.7807670291929021, total=   7.8s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=125, score=0.8283752860411899, total=   9.5s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=125, score=0.8260869565217391, total=  10.0s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=125, score=0.840870062965083, total=   9.7s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=150, score=0.852974828375286, total=  11.7s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=150, score=0.8426773455377574, total=  12.8s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=150, score=0.8528906697195192, total=  11.8s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=175, score=0.8707093821510298, total=  14.0s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=175, score=0.8615560640732265, total=  14.9s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=175, score=0.859187178019462, total=  13.7s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=200, score=0.8752860411899314, total=  16.2s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=200, score=0.8741418764302059, total=  16.5s
# [CV] learning_rate=0.001, max_depth=8, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=8, n_estimators=200, score=0.8649112764739554, total=  16.0s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=50, score=0.5011441647597255, total=   4.1s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=50, score=0.5011441647597255, total=   4.3s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=50, score=0.5014310246136233, total=   4.3s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=75, score=0.5011441647597255, total=   7.9s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=75, score=0.5011441647597255, total=   7.0s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=75 ...............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=75, score=0.5014310246136233, total=   7.3s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=100, score=0.772883295194508, total=   9.3s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=100, score=0.8032036613272311, total=   9.5s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=100, score=0.8208357183743561, total=   9.6s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=125, score=0.8438215102974829, total=  11.5s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=125, score=0.8243707093821511, total=  12.0s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=125 ..............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=125, score=0.842587292501431, total=  12.1s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=150, score=0.8609839816933639, total=  14.6s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=150, score=0.8438215102974829, total=  15.3s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=150 ..............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=150, score=0.8517458500286205, total=  14.6s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=175, score=0.8661327231121282, total=  17.1s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=175, score=0.8541189931350115, total=  17.1s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=175 ..............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=175, score=0.8580423583285632, total=  17.1s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=200, score=0.8729977116704806, total=  19.7s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=200, score=0.868421052631579, total=  19.5s
# [CV] learning_rate=0.001, max_depth=9, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=9, n_estimators=200, score=0.86090440755581, total=  21.5s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=50 ..............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=50, score=0.5011441647597255, total=   4.6s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=50 ..............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=50, score=0.5011441647597255, total=   5.0s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=50 ..............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=50, score=0.5014310246136233, total=   5.0s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=75 ..............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=75, score=0.5011441647597255, total=   7.3s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=75 ..............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=75, score=0.5011441647597255, total=   7.5s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=75 ..............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=75, score=0.5014310246136233, total=   7.4s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=100 .............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=100, score=0.7837528604118993, total=  10.2s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=100 .............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=100, score=0.7923340961098398, total=  10.7s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=100 .............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=100, score=0.8231253577561534, total=  12.2s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=125 .............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=125, score=0.8392448512585813, total=  14.9s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=125 .............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=125, score=0.8243707093821511, total=  16.5s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=125 .............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=125, score=0.8460217515741271, total=  15.9s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=150 .............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=150, score=0.8506864988558352, total=  20.1s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=150 .............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=150, score=0.8381006864988558, total=  15.9s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=150 .............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=150, score=0.8523182598740698, total=  16.4s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=175 .............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=175, score=0.8575514874141876, total=  23.2s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=175 .............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=175, score=0.8524027459954233, total=  29.5s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=175 .............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=175, score=0.8586147681740126, total=  29.5s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=200 .............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=200, score=0.8627002288329519, total=  30.8s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=200 .............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=200, score=0.8609839816933639, total=  28.2s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=200 .............
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=200, score=0.8620492272467086, total=  26.9s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=50, score=0.879862700228833, total=   1.7s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=50, score=0.8901601830663616, total=   2.3s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=50, score=0.8803663423010876, total=   2.1s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=75, score=0.8844393592677345, total=   3.5s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=75, score=0.8918764302059496, total=   2.8s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=75, score=0.8855180309101317, total=   2.7s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=100, score=0.8832951945080092, total=   3.6s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=100, score=0.8918764302059496, total=   3.9s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=100, score=0.884373211219233, total=   3.7s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=125, score=0.8850114416475973, total=   4.5s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=125, score=0.8907322654462243, total=   4.7s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=125, score=0.8866628506010303, total=   5.6s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=150, score=0.8890160183066361, total=   5.4s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=150, score=0.8924485125858124, total=   6.1s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=150, score=0.8849456210646823, total=   5.8s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=175, score=0.8890160183066361, total=   6.3s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=175, score=0.8941647597254004, total=   7.3s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=175, score=0.8883800801373783, total=   6.5s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=200, score=0.8890160183066361, total=   8.0s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=200, score=0.8964530892448512, total=   7.4s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=200, score=0.8889524899828277, total=   8.6s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=50, score=0.8844393592677345, total=   2.4s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=50, score=0.8907322654462243, total=   2.6s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=50, score=0.8809387521465369, total=   2.4s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=75, score=0.8895881006864989, total=   3.8s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=75, score=0.8958810068649885, total=   4.9s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=75, score=0.8815111619919863, total=   3.7s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=100, score=0.8907322654462243, total=   5.8s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=100, score=0.8964530892448512, total=   6.0s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=100, score=0.8849456210646823, total=   4.9s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=125, score=0.8930205949656751, total=   6.2s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=125, score=0.8941647597254004, total=   6.4s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=125, score=0.886090440755581, total=   6.1s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=150, score=0.8930205949656751, total=   8.1s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=150, score=0.8958810068649885, total=   7.5s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=150, score=0.8889524899828277, total=   8.4s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=175, score=0.8918764302059496, total=   8.8s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=175, score=0.898741418764302, total=   9.4s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=175, score=0.8900973096737264, total=   9.2s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=200, score=0.8941647597254004, total=  10.3s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=200, score=0.8993135011441648, total=  10.8s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=200, score=0.8900973096737264, total=  10.9s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=50, score=0.8844393592677345, total=   3.7s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=50, score=0.8981693363844394, total=   4.2s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=50, score=0.8866628506010303, total=   3.4s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=75, score=0.8907322654462243, total=   5.7s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=75, score=0.9010297482837528, total=   5.3s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=75, score=0.8883800801373783, total=   4.8s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=100, score=0.8941647597254004, total=   7.3s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=100, score=0.8975972540045767, total=   6.4s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=100, score=0.8889524899828277, total=   7.7s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=125, score=0.8924485125858124, total=   8.1s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=125, score=0.8993135011441648, total=   8.7s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=125, score=0.8900973096737264, total=   8.5s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=150, score=0.8953089244851259, total=  10.7s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=150, score=0.9016018306636155, total=  10.8s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=150, score=0.8906697195191757, total=  10.3s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=175, score=0.8941647597254004, total=  12.8s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=175, score=0.8993135011441648, total=  13.4s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=175, score=0.8918145392100744, total=  12.3s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=200, score=0.8998855835240275, total=  14.2s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=200, score=0.9021739130434783, total=  13.4s
# [CV] learning_rate=0.01, max_depth=6, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=6, n_estimators=200, score=0.8935317687464225, total=  13.2s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=50, score=0.8890160183066361, total=   4.4s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=50, score=0.8981693363844394, total=   4.1s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=50, score=0.886090440755581, total=   3.9s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=75, score=0.8918764302059496, total=   6.6s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=75, score=0.897025171624714, total=   6.4s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=75, score=0.8849456210646823, total=   5.9s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=100, score=0.8935926773455377, total=   8.6s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=100, score=0.9010297482837528, total=   8.2s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=100, score=0.8883800801373783, total=   9.2s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=125, score=0.8930205949656751, total=  11.0s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=125, score=0.898741418764302, total=  10.1s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=125, score=0.8872352604464797, total=  11.0s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=150, score=0.8964530892448512, total=  11.2s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=150, score=0.8998855835240275, total=  10.4s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=150, score=0.8872352604464797, total=  10.6s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=175, score=0.897025171624714, total=  12.5s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=175, score=0.9010297482837528, total=  12.3s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=175, score=0.8895248998282771, total=  12.1s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=200, score=0.8981693363844394, total=  14.0s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=200, score=0.9016018306636155, total=  14.4s
# [CV] learning_rate=0.01, max_depth=7, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=7, n_estimators=200, score=0.8895248998282771, total=  14.2s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=50, score=0.8901601830663616, total=   4.1s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=50, score=0.8901601830663616, total=   4.4s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=50, score=0.8832283915283343, total=   4.1s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=75, score=0.8930205949656751, total=   6.2s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=75, score=0.8958810068649885, total=   6.8s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=75, score=0.8849456210646823, total=   6.2s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=100, score=0.898741418764302, total=   8.8s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=100, score=0.8998855835240275, total=   8.6s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=100, score=0.8849456210646823, total=   8.8s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=125, score=0.897025171624714, total=  10.7s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=125, score=0.8998855835240275, total=  11.0s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=125, score=0.8866628506010303, total=  11.6s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=150, score=0.8964530892448512, total=  13.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=150, score=0.8981693363844394, total=  13.2s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=150, score=0.8883800801373783, total=  13.0s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=175, score=0.897025171624714, total=  15.2s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=175, score=0.8993135011441648, total=  15.8s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=175, score=0.8900973096737264, total=  16.6s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=200, score=0.9004576659038902, total=  17.9s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=200, score=0.8998855835240275, total=  18.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=200, score=0.8883800801373783, total=  17.8s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=50, score=0.8913043478260869, total=   4.8s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=50, score=0.8953089244851259, total=   5.0s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=50, score=0.884373211219233, total=   5.1s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=75, score=0.8867276887871853, total=   7.5s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=75, score=0.8935926773455377, total=   8.1s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=75 ................
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=75, score=0.8820835718374356, total=   7.5s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=100, score=0.8941647597254004, total=  10.6s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=100, score=0.8947368421052632, total=  10.6s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=100, score=0.8883800801373783, total=  10.3s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=125, score=0.897025171624714, total=  13.3s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=125, score=0.8924485125858124, total=  14.0s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=125 ...............
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=125, score=0.8889524899828277, total=  13.4s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=150, score=0.8947368421052632, total=  15.8s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=150, score=0.8941647597254004, total=  16.2s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=150 ...............
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=150, score=0.8912421293646251, total=  16.0s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=175, score=0.8941647597254004, total=  18.6s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=175, score=0.8953089244851259, total=  18.7s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=175 ...............
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=175, score=0.8895248998282771, total=  19.1s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=200, score=0.8958810068649885, total=  21.5s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=200, score=0.898741418764302, total=  21.5s
# [CV] learning_rate=0.01, max_depth=9, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=9, n_estimators=200, score=0.8900973096737264, total=  21.8s
# [CV] learning_rate=0.01, max_depth=10, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=50, score=0.8844393592677345, total=   5.8s
# [CV] learning_rate=0.01, max_depth=10, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=50, score=0.8895881006864989, total=   5.6s
# [CV] learning_rate=0.01, max_depth=10, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=50, score=0.8809387521465369, total=   5.9s
# [CV] learning_rate=0.01, max_depth=10, n_estimators=75 ...............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=75, score=0.8890160183066361, total=   8.8s
# [CV] learning_rate=0.01, max_depth=10, n_estimators=75 ...............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=75, score=0.8924485125858124, total=   9.3s
# [CV] learning_rate=0.01, max_depth=10, n_estimators=75 ...............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=75, score=0.8820835718374356, total=   8.9s
# [CV] learning_rate=0.01, max_depth=10, n_estimators=100 ..............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=100, score=0.8901601830663616, total=  14.4s
# [CV] learning_rate=0.01, max_depth=10, n_estimators=100 ..............
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=100, score=0.8901601830663616, total=  12.6s
# [CV] learning_rate=0.01, max_depth=10, n_estimators=100 ..............
# ...
# [CV]  learning_rate=1, max_depth=6, n_estimators=150, score=0.8947368421052632, total=   2.1s
# [CV] learning_rate=1, max_depth=6, n_estimators=150 ..................
# [CV]  learning_rate=1, max_depth=6, n_estimators=150, score=0.8797939324556382, total=   1.9s
# [CV] learning_rate=1, max_depth=6, n_estimators=175 ..................
# [CV]  learning_rate=1, max_depth=6, n_estimators=175, score=0.8958810068649885, total=   2.1s
# [CV] learning_rate=1, max_depth=6, n_estimators=175 ..................
# [CV]  learning_rate=1, max_depth=6, n_estimators=175, score=0.8941647597254004, total=   2.2s
# [CV] learning_rate=1, max_depth=6, n_estimators=175 ..................
# [CV]  learning_rate=1, max_depth=6, n_estimators=175, score=0.8815111619919863, total=   2.3s
# [CV] learning_rate=1, max_depth=6, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=6, n_estimators=200, score=0.8935926773455377, total=   3.1s
# [CV] learning_rate=1, max_depth=6, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=6, n_estimators=200, score=0.8947368421052632, total=   2.6s
# [CV] learning_rate=1, max_depth=6, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=6, n_estimators=200, score=0.8855180309101317, total=   2.3s
# [CV] learning_rate=1, max_depth=7, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=7, n_estimators=50, score=0.8913043478260869, total=   1.8s
# [CV] learning_rate=1, max_depth=7, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=7, n_estimators=50, score=0.8924485125858124, total=   1.8s
# [CV] learning_rate=1, max_depth=7, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=7, n_estimators=50, score=0.8906697195191757, total=   1.7s
# [CV] learning_rate=1, max_depth=7, n_estimators=75 ...................
# [CV]  learning_rate=1, max_depth=7, n_estimators=75, score=0.8941647597254004, total=   1.9s
# [CV] learning_rate=1, max_depth=7, n_estimators=75 ...................
# [CV]  learning_rate=1, max_depth=7, n_estimators=75, score=0.8935926773455377, total=   2.5s
# [CV] learning_rate=1, max_depth=7, n_estimators=75 ...................
# [CV]  learning_rate=1, max_depth=7, n_estimators=75, score=0.8906697195191757, total=   2.3s
# [CV] learning_rate=1, max_depth=7, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=7, n_estimators=100, score=0.8890160183066361, total=   1.8s
# [CV] learning_rate=1, max_depth=7, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=7, n_estimators=100, score=0.8924485125858124, total=   1.9s
# [CV] learning_rate=1, max_depth=7, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=7, n_estimators=100, score=0.882655981682885, total=   1.8s
# [CV] learning_rate=1, max_depth=7, n_estimators=125 ..................
# [CV]  learning_rate=1, max_depth=7, n_estimators=125, score=0.8935926773455377, total=   1.8s
# [CV] learning_rate=1, max_depth=7, n_estimators=125 ..................
# [CV]  learning_rate=1, max_depth=7, n_estimators=125, score=0.8913043478260869, total=   2.0s
# [CV] learning_rate=1, max_depth=7, n_estimators=125 ..................
# [CV]  learning_rate=1, max_depth=7, n_estimators=125, score=0.8900973096737264, total=   1.9s
# [CV] learning_rate=1, max_depth=7, n_estimators=150 ..................
# [CV]  learning_rate=1, max_depth=7, n_estimators=150, score=0.8930205949656751, total=   1.8s
# [CV] learning_rate=1, max_depth=7, n_estimators=150 ..................
# [CV]  learning_rate=1, max_depth=7, n_estimators=150, score=0.8918764302059496, total=   2.0s
# [CV] learning_rate=1, max_depth=7, n_estimators=150 ..................
# [CV]  learning_rate=1, max_depth=7, n_estimators=150, score=0.8809387521465369, total=   1.8s
# [CV] learning_rate=1, max_depth=7, n_estimators=175 ..................
# [CV]  learning_rate=1, max_depth=7, n_estimators=175, score=0.8930205949656751, total=   1.9s
# [CV] learning_rate=1, max_depth=7, n_estimators=175 ..................
# [CV]  learning_rate=1, max_depth=7, n_estimators=175, score=0.8924485125858124, total=   2.0s
# [CV] learning_rate=1, max_depth=7, n_estimators=175 ..................
# [CV]  learning_rate=1, max_depth=7, n_estimators=175, score=0.8803663423010876, total=   1.9s
# [CV] learning_rate=1, max_depth=7, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=7, n_estimators=200, score=0.8918764302059496, total=   1.9s
# [CV] learning_rate=1, max_depth=7, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=7, n_estimators=200, score=0.8918764302059496, total=   2.1s
# [CV] learning_rate=1, max_depth=7, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=7, n_estimators=200, score=0.882655981682885, total=   2.0s
# [CV] learning_rate=1, max_depth=8, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=8, n_estimators=50, score=0.8964530892448512, total=   1.6s
# [CV] learning_rate=1, max_depth=8, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=8, n_estimators=50, score=0.8918764302059496, total=   1.7s
# [CV] learning_rate=1, max_depth=8, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=8, n_estimators=50, score=0.8838008013737836, total=   1.6s
# [CV] learning_rate=1, max_depth=8, n_estimators=75 ...................
# [CV]  learning_rate=1, max_depth=8, n_estimators=75, score=0.8941647597254004, total=   1.7s
# [CV] learning_rate=1, max_depth=8, n_estimators=75 ...................
# [CV]  learning_rate=1, max_depth=8, n_estimators=75, score=0.8913043478260869, total=   1.8s
# [CV] learning_rate=1, max_depth=8, n_estimators=75 ...................
# [CV]  learning_rate=1, max_depth=8, n_estimators=75, score=0.8820835718374356, total=   1.7s
# [CV] learning_rate=1, max_depth=8, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=8, n_estimators=100, score=0.8947368421052632, total=   1.7s
# [CV] learning_rate=1, max_depth=8, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=8, n_estimators=100, score=0.8930205949656751, total=   1.8s
# [CV] learning_rate=1, max_depth=8, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=8, n_estimators=100, score=0.8820835718374356, total=   1.7s
# [CV] learning_rate=1, max_depth=8, n_estimators=125 ..................
# [CV]  learning_rate=1, max_depth=8, n_estimators=125, score=0.8947368421052632, total=   1.8s
# [CV] learning_rate=1, max_depth=8, n_estimators=125 ..................
# [CV]  learning_rate=1, max_depth=8, n_estimators=125, score=0.8981693363844394, total=   1.8s
# [CV] learning_rate=1, max_depth=8, n_estimators=125 ..................
# [CV]  learning_rate=1, max_depth=8, n_estimators=125, score=0.8866628506010303, total=   1.7s
# [CV] learning_rate=1, max_depth=8, n_estimators=150 ..................
# [CV]  learning_rate=1, max_depth=8, n_estimators=150, score=0.8930205949656751, total=   1.8s
# [CV] learning_rate=1, max_depth=8, n_estimators=150 ..................
# [CV]  learning_rate=1, max_depth=8, n_estimators=150, score=0.8941647597254004, total=   1.9s
# [CV] learning_rate=1, max_depth=8, n_estimators=150 ..................
# [CV]  learning_rate=1, max_depth=8, n_estimators=150, score=0.882655981682885, total=   1.7s
# [CV] learning_rate=1, max_depth=8, n_estimators=175 ..................
# [CV]  learning_rate=1, max_depth=8, n_estimators=175, score=0.8947368421052632, total=   1.8s
# [CV] learning_rate=1, max_depth=8, n_estimators=175 ..................
# [CV]  learning_rate=1, max_depth=8, n_estimators=175, score=0.8913043478260869, total=   2.0s
# [CV] learning_rate=1, max_depth=8, n_estimators=175 ..................
# [CV]  learning_rate=1, max_depth=8, n_estimators=175, score=0.8929593589009731, total=   1.8s
# [CV] learning_rate=1, max_depth=8, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=8, n_estimators=200, score=0.8935926773455377, total=   1.9s
# [CV] learning_rate=1, max_depth=8, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=8, n_estimators=200, score=0.8935926773455377, total=   2.0s
# [CV] learning_rate=1, max_depth=8, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=8, n_estimators=200, score=0.8906697195191757, total=   1.8s
# [CV] learning_rate=1, max_depth=9, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=9, n_estimators=50, score=0.8981693363844394, total=   1.5s
# [CV] learning_rate=1, max_depth=9, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=9, n_estimators=50, score=0.8947368421052632, total=   1.5s
# [CV] learning_rate=1, max_depth=9, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=9, n_estimators=50, score=0.8838008013737836, total=   1.4s
# [CV] learning_rate=1, max_depth=9, n_estimators=75 ...................
# [CV]  learning_rate=1, max_depth=9, n_estimators=75, score=0.9004576659038902, total=   1.5s
# [CV] learning_rate=1, max_depth=9, n_estimators=75 ...................
# [CV]  learning_rate=1, max_depth=9, n_estimators=75, score=0.8953089244851259, total=   1.6s
# [CV] learning_rate=1, max_depth=9, n_estimators=75 ...................
# [CV]  learning_rate=1, max_depth=9, n_estimators=75, score=0.8792215226101889, total=   1.5s
# [CV] learning_rate=1, max_depth=9, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=9, n_estimators=100, score=0.8958810068649885, total=   1.7s
# [CV] learning_rate=1, max_depth=9, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=9, n_estimators=100, score=0.8924485125858124, total=   1.7s
# [CV] learning_rate=1, max_depth=9, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=9, n_estimators=100, score=0.8855180309101317, total=   1.6s
# [CV] learning_rate=1, max_depth=9, n_estimators=125 ..................
# [CV]  learning_rate=1, max_depth=9, n_estimators=125, score=0.8941647597254004, total=   1.6s
# [CV] learning_rate=1, max_depth=9, n_estimators=125 ..................
# [CV]  learning_rate=1, max_depth=9, n_estimators=125, score=0.8998855835240275, total=   1.7s
# [CV] learning_rate=1, max_depth=9, n_estimators=125 ..................
# [CV]  learning_rate=1, max_depth=9, n_estimators=125, score=0.8849456210646823, total=   1.6s
# [CV] learning_rate=1, max_depth=9, n_estimators=150 ..................
# [CV]  learning_rate=1, max_depth=9, n_estimators=150, score=0.8993135011441648, total=   1.7s
# [CV] learning_rate=1, max_depth=9, n_estimators=150 ..................
# [CV]  learning_rate=1, max_depth=9, n_estimators=150, score=0.8981693363844394, total=   1.8s
# [CV] learning_rate=1, max_depth=9, n_estimators=150 ..................
# [CV]  learning_rate=1, max_depth=9, n_estimators=150, score=0.8763594733829422, total=   1.7s
# [CV] learning_rate=1, max_depth=9, n_estimators=175 ..................
# [CV]  learning_rate=1, max_depth=9, n_estimators=175, score=0.8998855835240275, total=   1.8s
# [CV] learning_rate=1, max_depth=9, n_estimators=175 ..................
# [CV]  learning_rate=1, max_depth=9, n_estimators=175, score=0.9016018306636155, total=   1.8s
# [CV] learning_rate=1, max_depth=9, n_estimators=175 ..................
# [CV]  learning_rate=1, max_depth=9, n_estimators=175, score=0.8872352604464797, total=   1.7s
# [CV] learning_rate=1, max_depth=9, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=9, n_estimators=200, score=0.8941647597254004, total=   1.8s
# [CV] learning_rate=1, max_depth=9, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=9, n_estimators=200, score=0.8975972540045767, total=   1.8s
# [CV] learning_rate=1, max_depth=9, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=9, n_estimators=200, score=0.8900973096737264, total=   1.7s
# [CV] learning_rate=1, max_depth=10, n_estimators=50 ..................
# [CV]  learning_rate=1, max_depth=10, n_estimators=50, score=0.8947368421052632, total=   1.5s
# [CV] learning_rate=1, max_depth=10, n_estimators=50 ..................
# [CV]  learning_rate=1, max_depth=10, n_estimators=50, score=0.8918764302059496, total=   1.5s
# [CV] learning_rate=1, max_depth=10, n_estimators=50 ..................
# [CV]  learning_rate=1, max_depth=10, n_estimators=50, score=0.8935317687464225, total=   1.4s
# [CV] learning_rate=1, max_depth=10, n_estimators=75 ..................
# [CV]  learning_rate=1, max_depth=10, n_estimators=75, score=0.8918764302059496, total=   1.5s
# [CV] learning_rate=1, max_depth=10, n_estimators=75 ..................
# [CV]  learning_rate=1, max_depth=10, n_estimators=75, score=0.8867276887871853, total=   1.6s
# [CV] learning_rate=1, max_depth=10, n_estimators=75 ..................
# [CV]  learning_rate=1, max_depth=10, n_estimators=75, score=0.8895248998282771, total=   1.7s
# [CV] learning_rate=1, max_depth=10, n_estimators=100 .................
# [CV]  learning_rate=1, max_depth=10, n_estimators=100, score=0.8941647597254004, total=   1.7s
# [CV] learning_rate=1, max_depth=10, n_estimators=100 .................
# [CV]  learning_rate=1, max_depth=10, n_estimators=100, score=0.8918764302059496, total=   1.8s
# [CV] learning_rate=1, max_depth=10, n_estimators=100 .................
# [CV]  learning_rate=1, max_depth=10, n_estimators=100, score=0.8935317687464225, total=   1.7s
# [CV] learning_rate=1, max_depth=10, n_estimators=125 .................
# [CV]  learning_rate=1, max_depth=10, n_estimators=125, score=0.8930205949656751, total=   1.8s
# [CV] learning_rate=1, max_depth=10, n_estimators=125 .................
# [CV]  learning_rate=1, max_depth=10, n_estimators=125, score=0.8941647597254004, total=   3.3s
# [CV] learning_rate=1, max_depth=10, n_estimators=125 .................
# [CV]  learning_rate=1, max_depth=10, n_estimators=125, score=0.887807670291929, total=   2.1s
# [CV] learning_rate=1, max_depth=10, n_estimators=150 .................
# [CV]  learning_rate=1, max_depth=10, n_estimators=150, score=0.8895881006864989, total=   2.2s
# [CV] learning_rate=1, max_depth=10, n_estimators=150 .................
# [CV]  learning_rate=1, max_depth=10, n_estimators=150, score=0.8884439359267735, total=   1.8s
# [CV] learning_rate=1, max_depth=10, n_estimators=150 .................
# [CV]  learning_rate=1, max_depth=10, n_estimators=150, score=0.8889524899828277, total=   1.6s
# [CV] learning_rate=1, max_depth=10, n_estimators=175 .................
# [CV]  learning_rate=1, max_depth=10, n_estimators=175, score=0.8924485125858124, total=   1.7s
# [CV] learning_rate=1, max_depth=10, n_estimators=175 .................
# [CV]  learning_rate=1, max_depth=10, n_estimators=175, score=0.8878718535469108, total=   2.1s
# [CV] learning_rate=1, max_depth=10, n_estimators=175 .................
# [CV]  learning_rate=1, max_depth=10, n_estimators=175, score=0.8866628506010303, total=   1.8s
# [CV] learning_rate=1, max_depth=10, n_estimators=200 .................
# [CV]  learning_rate=1, max_depth=10, n_estimators=200, score=0.8941647597254004, total=   2.0s
# [CV] learning_rate=1, max_depth=10, n_estimators=200 .................
# [CV]  learning_rate=1, max_depth=10, n_estimators=200, score=0.8867276887871853, total=   1.7s
# [CV] learning_rate=1, max_depth=10, n_estimators=200 .................
# [CV]  learning_rate=1, max_depth=10, n_estimators=200, score=0.8895248998282771, total=   1.6s
# [Parallel(n_jobs=1)]: Done 882 out of 882 | elapsed: 113.2min finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_sampl...      subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'learning_rate': [0.001, 0.01, 0.05, 0.1, 0.5, 1], 'n_estimators': [50, 75, 100, 125, 150, 175, 200], 'max_depth': [4, 5, 6, 7, 8, 9, 10]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=3)

# %%
print('The best parameters to use are: ', grid.best_params_)
# Out:
# The best parameters to use are:  {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 125}

# %%
# Create the GradientBoostingClassifier object and train it
#learning_rate = 0.05, n_estimators = 125, 

gbc = GradientBoostingClassifier(learning_rate = 0.05, n_estimators = 125, max_depth = 6, random_state = 42).fit(X_train, y_train)

#Make a prediction for the X_test
prediction = gbc.predict(X_test)

print('Training set score: {:.3f}'.format(gbc.score(X_train, y_train)))
print('Test set score: {:.3f}'.format(gbc.score(X_test, y_test)))
# Out:
# Training set score: 0.989
# Test set score: 0.910

# %%
# Show the feature importances with its feature name
sorted(zip(gbc.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.22926179260886562, 'koi_fpflag_co'),
#  (0.19545045595536145, 'koi_fpflag_nt'),
#  (0.15069859635801372, 'koi_fpflag_ss'),
#  (0.08468235677463487, 'koi_model_snr'),
#  (0.0688837060888711, 'koi_steff_err1'),
#  (0.03305093288443346, 'koi_fpflag_ec'),
#  (0.031757020410977346, 'koi_prad'),
#  (0.022742785209558726, 'koi_duration_err1'),
#  (0.016817087748584144, 'koi_duration'),
#  (0.015380103169373119, 'koi_duration_err2'),
#  (0.015336013678980792, 'koi_impact'),
#  (0.013598697900983262, 'koi_period'),
#  (0.01076738978632558, 'koi_prad_err2'),
#  (0.010128898450673303, 'ra'),
#  (0.007786922545530026, 'koi_kepmag'),
#  (0.007621726568738126, 'koi_time0bk'),
#  (0.00737194622570606, 'koi_depth'),
#  (0.005920728855064126, 'koi_tce_plnt_num'),
#  (0.005888023469728091, 'dec'),
#  (0.005629871213355953, 'koi_prad_err1'),
#  (0.005360647966358493, 'koi_impact_err2'),
#  (0.005186715336138058, 'koi_steff_err2'),
#  (0.005098122969890742, 'koi_depth_err1'),
#  (0.004186727675294336, 'koi_depth_err2'),
#  (0.0037042384874531576, 'koi_slogg_err1'),
#  (0.0036111464210979646, 'koi_steff'),
#  (0.003540306133147842, 'koi_srad_err1'),
#  (0.0034734768685205993, 'koi_slogg_err2'),
#  (0.0034665027145565335, 'koi_time0bk_err1'),
#  (0.002904777634314541, 'koi_teq'),
#  (0.002756441131495618, 'koi_impact_err1'),
#  (0.002433981456267592, 'koi_time0bk_err2'),
#  (0.00240653279545204, 'koi_slogg'),
#  (0.0023781598652248617, 'koi_period_err1'),
#  (0.0022253931255002673, 'koi_period_err2'),
#  (0.002215171495061043, 'koi_srad_err2'),
#  (0.0018162510400747023, 'koi_insol_err1'),
#  (0.0016388755619416847, 'koi_insol_err2'),
#  (0.0016201635945073207, 'koi_srad'),
#  (0.0012013118239437132, 'koi_insol')]

# %%
# %matplotlib inline

fig, ax = plt.subplots(figsize = (15, 12))



y_pos = np.arange(len(feature_names))

ax.barh(y_pos, gbc.feature_importances_, align='center', color = 'orange')

ax.set_xticks(np.linspace(0, 0.25,10))
ax.set_yticks(y_pos)
ax.set_yticklabels(feature_names)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Feature importance', size = 15)
ax.set_ylabel('Feature name', size = 15)
ax.grid()

ax.set_title('Feature importances of Gradient Boosting Classifier', size  = 25)


plt.show()
